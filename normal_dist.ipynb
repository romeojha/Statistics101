# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %% [markdown]
# parametric and non parametric
# parametric

# %%
sns.distplot(df["petal_length"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13576\2807225282.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["petal_length"])
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.displot(data=df,x=df["petal_width"],hue=df["species"])

# %%
sns.distplot(df["sepal_width"])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_13576\664177273.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["sepal_width"])
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
# note that we cannot plot as a curve because there is no distribution like this. so we use non parametric estimation
#for estimating the underlying distribution
#---------------------------
#sns.distplot(df["sepal_length"])
sns.displot(data=df, x="sepal_length", hue="species")

# %%
#qs? can we hue iun distplot or parametric. if not then why?

# %% [markdown]
# non parametric method for probability estimation

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.kdeplot(data=df,x="sepal_length",hue=df["species"])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="sepal_width",hue=df["species"])
# Out:
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="petal_width",hue=df["species"])
# Out:
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(data=df,x="petal_length",hue=df["species"])
# Out:
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.load_dataset('titanic')
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 0           0       3    male  22.0      1      0   7.2500        S   Third  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
